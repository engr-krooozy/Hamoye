# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Question1
# If you have the following list
#
# lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
#
# col = [‘Age’,’Nationality’,’Overall’]
#
# How do you create a pandas DataFrame using this list, to look like the table below?

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age', 'Nationality', 'Overall']

pd.DataFrame(lst, columns = col, index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [raw]
# Given the following numpy array
#
# array  = ([[94, **89, 63**],
#
#              [93, **92, 48**],
#
#              [92, 94, 56]])
#
# How would you select  the elements in bold and italics from the array?

# %%
df  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
#df.shape()

#len(df)

#pd.length(df)

print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-859b66f8f68c> in <module>()
#       5 #pd.length(df)
#       6
# ----> 7 print(df.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ce1543b3be47> in <module>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x = y[1][-1]

# %%
print(x)
# Out:
# 8

# %%
df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG - FoodBalanceSheets_E_Africa_NOFLAG.csv')
df
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 0              4   Algeria       2501                Population           511
# 1              4   Algeria       2501                Population          5301
# 2              4   Algeria       2901               Grand Total           664
# 3              4   Algeria       2901               Grand Total           674
# 4              4   Algeria       2901               Grand Total           684
# 5              4   Algeria       2903          Vegetal Products           664
# 6              4   Algeria       2903          Vegetal Products           674
# 7              4   Algeria       2903          Vegetal Products           684
# 8              4   Algeria       2941           Animal Products           664
# 9              4   Algeria       2941           Animal Products           674
# 10             4   Algeria       2941           Animal Products           684
# ...

# %%
df.info()    #showing the info of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.nunique()    #unique properties of the dataframe
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %% [markdown]
# # Question 11
#
# What is the total sum of Animal Fat produced in 2014 and 2017 respectively?

# %%
(df.groupby('Item').sum()[['Y2014', 'Y2017']]).loc['Animal fats']
# Out:
# Y2014    209460.54
# Y2017    269617.53
# Name: Animal fats, dtype: float64

# %% [markdown]
# # Question 12
# What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
df.describe(include='all').loc[['mean','std'],['Y2015']]
# Out:
#             Y2015
# mean   135.235966
# std   1603.403984

# %% [markdown]
# # Question 13
# What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
print(df['Y2016'].isnull().sum())
# Out:
# 1535

# %%
print(df['Y2016'].isnull().sum() * 100 / df['Y2016'].count())
# Out:
# 2.583827093994075

# %% [markdown]
# # Question 14
# Which year had the highest correlation with ‘Element Code’?

# %%
df.corr(method ='pearson')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# # Question 15
# What year has the highest sum of Import Quantity?

# %%
df.groupby("Element").sum().loc['Import Quantity'].sort_values(ascending=False)
# Out:
# Element Code    28834929.00
# Item Code       13795966.00
# Area Code         688174.00
# Y2017             294559.09
# Y2018             287997.09
# Y2016             286582.78
# Y2014             274144.48
# Y2015             267018.46
# Name: Import Quantity, dtype: float64

# %% [markdown]
# # Question 16
# What is the total number of the sum of Production in 2014?

# %%
df.groupby("Element")['Y2014'].sum().sort_values(ascending=False)['Production']
# Out:
# 1931287.7500000005

# %% [markdown]
# # Question 17
# Which of these elements had the highest sum in 2018?

# %%
df.groupby("Element")['Y2018'].sum().sort_values(ascending=False)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Production                                2075072.89
# Food                                      1303841.28
# Total Population - Both sexes             1140605.00
# Food supply (kcal/capita/day)              455261.00
# Processing                                 308429.00
# Import Quantity                            287997.09
# Feed                                       233489.68
# Export Quantity                            181594.80
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Food supply quantity (kg/capita/yr)         49056.85
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Protein supply quantity (g/capita/day)      11833.56
# Fat supply quantity (g/capita/day)          10258.69
# Tourist consumption                            90.00
# ...

# %% [markdown]
# # Question 19
# What is the total Import Quantity in Algeria in 2018?

# %%
df[df["Area"] == 'Algeria'].groupby('Element')['Y2018'].sum().loc['Import Quantity']
# Out:
# 36238.29

# %% [markdown]
# # Question 20
# What is the total number of unique countries in the dataset?

# %%
len(df.groupby("Area")["Area"].count())
# Out:
# 49
